# %% [markdown]
# Purpose: Prepare data for XGBoost regression.<br>
# Author: Anna Pardo<br>
# Date initiated: Dec. 19, 2025

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler
from functools import reduce

# %%
# load Yg TPM
mdtpm = pd.read_csv("~/Yucca_genomics/rna_insilico_genome/TPM/Yg_toYgIS_allTPM_correctedmd_over1mil.txt",sep="\t",header="infer")
mdtpm.head()
# Out:
# /tmp/ipykernel_256/2025937544.py:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   mdtpm = pd.read_csv("~/Yucca_genomics/rna_insilico_genome/TPM/Yg_toYgIS_allTPM_correctedmd_over1mil.txt",sep="\t",header="infer")
#   sample_name genotype  time treat    ZT   species  Yucal.01G000100.v2.1  \
# 0          Y1       18   1.0     W   1.0  gloriosa             34.002815
# 1         Y10      2AB   1.5     W   3.0  gloriosa             40.070758
# 2        Y100      2AB   6.5     W  23.0  gloriosa             47.402599
# 3        Y101      2AB   1.0     D   1.0  gloriosa             57.062380
# 4        Y103      2AB   1.0     D   1.0  gloriosa             34.679279
#
#    Yucal.01G000200.v2.1  Yucal.01G000300.v2.1  Yucal.01G000400.v2.1  ...  \
# 0              4.546167                   0.0             17.236119  ...
# 1              3.628454                   0.0             14.918115  ...
# 2              5.201760                   0.0             17.406497  ...
# 3              6.374324                   0.0             10.567561  ...
# 4              6.087451                   0.0             11.115252  ...
#
#    YufilH1095122m.g  YufilH1095123m.g  YufilH1095125m.g  YufilH1095126m.g  \
# 0          0.000000          6.167441          1.435253          0.279077
# 1          0.713535          2.197522         15.695904          1.193256
# 2          0.314746          2.261806         21.742515          1.798380
# 3          0.000000          1.072366         27.573939          1.164591
# 4          0.000000          0.914550         28.621412          0.869052
#
#    YufilH1095128m.g  YufilH1095131m.g  YufilH1095132m.g  YufilH1095134m.g  \
# 0         11.420139          0.662252          1.886709          6.675105
# 1         10.172780          0.000000          2.214483         12.125756
# 2         10.256681          1.748663          2.075757         25.215640
# 3          9.105769          1.257431          2.431447          4.508369
# 4          7.076224          0.515567          2.419222          4.625880
#
#    YufilH1095146m.g  YufilH1095147m.g
# 0               0.0          0.000000
# 1               0.0          0.000000
# 2               0.0          1.838780
# 3               0.0          0.813682
# 4               0.0          0.867418
#
# [5 rows x 85968 columns]

# %%
mdtpm.drop(["time","species"],axis=1,inplace=True)

# %%
mdtpm["genotype"] = mdtpm["genotype"].astype(str)
mdtpm["genotype"].unique()
# Out:
# array(['18', '2AB', '1AB', '19', '15', 'Eudy', 'G', '56', '36', '13',
#        '45', '52', '43', '37', '48', '55', '70', '61', '51', '46', '53',
#        '16', '6', '12', '20', '50'], dtype=object)

# %%
zttpm = mdtpm[mdtpm["ZT"].isin([1.0,5.0,9.0,13.0,17.0,21.0])]

# %%
mdonly = zttpm[["sample_name","genotype","treat","ZT"]]

# %%
# check how many and which genotypes have complete data (at least 1 replicate in each treatment+ZT)
def iscomplete(gt):
    gtmd = mdonly[mdonly["genotype"]==gt]
    gtcount = gtmd.groupby(["treat","ZT"]).count().reset_index()[["treat","ZT","sample_name"]].rename(columns={"sample_name":"nreps"})
    if len(gtcount.index)==12:
        return "complete"
    elif len(gtcount.index)<12:
        return "incomplete"

# %%
dfdict={"Genotype":[],"Complete":[]}
for g in mdonly["genotype"].unique():
    dfdict['Genotype'].append(g)
    dfdict['Complete'].append(iscomplete(g))

# %%
cdf = pd.DataFrame(dfdict)

# %%
cdf[cdf["Complete"]=="incomplete"]
# Out:
#    Genotype    Complete
# 4        15  incomplete
# 11       52  incomplete
# 15       55  incomplete
# 16       70  incomplete
# 20       53  incomplete
# 21       16  incomplete
# 24       20  incomplete
# 25       50  incomplete

# %%
def iscompletedf(gt):
    gtmd = mdonly[mdonly["genotype"]==gt]
    gtcount = gtmd.groupby(["treat","ZT"]).count().reset_index()[["treat","ZT","sample_name"]].rename(columns={"sample_name":"nreps"})
    return gtcount

# %%
complete_gts = list(cdf[cdf["Complete"]=="complete"]["Genotype"])

# %%
len(complete_gts)
# Out:
# 18

# %%
comptpm = zttpm[zttpm["genotype"].isin(complete_gts)]

# %%
list(cdf[cdf["Complete"]=="incomplete"]["Genotype"])
# Out:
# ['15', '52', '55', '70', '53', '16', '20', '50']

# %%
# for comptpm: filter out genes that are expressed in <10% of genotypes (i.e., expressed only in 1 or 2 genotypes)
def egtnum(gid):
    tpmsub = comptpm[["genotype",gid]]
    maxtpm = tpmsub.groupby("genotype").max().reset_index()
    # count the number of genotypes with max>0
    max0 = maxtpm[maxtpm[gid]>0]
    return len(max0)

# %%
dropgenes = []
for c in comptpm.columns:
    if c.startswith("Y"):
        if egtnum(c)<=2:
            dropgenes.append(c)

# %%
len(dropgenes)
# Out:
# 4143

# %%
len(comptpm.columns)-4
# Out:
# 85962

# %%
filtcomp = comptpm.drop(dropgenes,axis=1)

# %%
len(filtcomp.columns)-4
# Out:
# 81819

# %%
# drop zero-variance genes
def variance_threshold_selector(data):
    selector = VarianceThreshold()
    selector.fit(data)
    return data[data.columns[selector.get_support(indices=True)]]

# %%
filttpm = filtcomp.set_index(["sample_name","genotype","treat","ZT"])

# %%
vttpm = variance_threshold_selector(filttpm)

# %%
print("Number of zero-variance genes removed:",len(filttpm.columns)-len(vttpm.columns))
# Out:
# Number of zero-variance genes removed: 0

# %%
vttpm_log = vttpm.apply(lambda x: np.log2(x+1))

# %%
vttpm_log.reset_index(inplace=True)

# %%
vttpm_log.drop("sample_name",axis=1,inplace=True)

# %%
vttpm_log["treat_ZT"] = vttpm_log["treat"]+"_"+vttpm_log["ZT"].astype(int).astype(str)
vttpm_log.head()
# Out:
#   genotype treat    ZT  Yucal.01G000100.v2.1  Yucal.01G000200.v2.1  \
# 0       18     W   1.0              5.129399              2.471491
# 1      2AB     D   1.0              5.859532              2.882511
# 2      2AB     D   1.0              5.157015              2.825267
# 3      1AB     W  21.0              5.791442              2.753920
# 4       18     W  21.0              5.596679              3.241637
#
#    Yucal.01G000300.v2.1  Yucal.01G000400.v2.1  Yucal.01G000500.v2.1  \
# 0                   0.0              4.188727              2.140948
# 1                   0.0              3.532013              2.045877
# 2                   0.0              3.598753              2.070301
# 3                   0.0              4.225544              1.127059
# 4                   0.0              4.047620              1.632024
#
#    Yucal.01G000600.v2.1  Yucal.01G000700.v2.1  ...  YufilH1095122m.g  \
# 0              3.181674              3.168583  ...               0.0
# 1              3.441016              2.950223  ...               0.0
# 2              3.257171              2.777274  ...               0.0
# 3              2.864516              2.795164  ...               0.0
# 4              3.407077              3.284910  ...               0.0
#
#    YufilH1095123m.g  YufilH1095125m.g  YufilH1095126m.g  YufilH1095128m.g  \
# 0          2.841458          1.284072          0.355103          3.634609
# 1          1.051279          4.836628          1.114095          3.337107
# 2          0.937005          4.888569          0.902307          3.013681
# 3          1.217595          4.454795          1.659643          3.064140
# 4          3.086022          1.656996          2.910847          3.955409
#
#    YufilH1095131m.g  YufilH1095132m.g  YufilH1095134m.g  YufilH1095147m.g  \
# 0          0.733139          1.529426          2.940186          0.000000
# 1          1.174682          1.778817          2.461625          0.858921
# 2          0.599857          1.773668          2.492079          0.901045
# 3          0.000000          1.809274          4.059519          0.000000
# 4          1.919294          1.736134          4.441396          0.000000
#
#    treat_ZT
# 0       W_1
# 1       D_1
# 2       D_1
# 3      W_21
# 4      W_21
#
# [5 rows x 81823 columns]

# %%
vttpm_log.drop(["treat","ZT"],axis=1,inplace=True)

# %%
# calculate mean expression of each gene on a per-treatment/ZT basis
## define a function to do this
def genemeans(gid):
    sublog = vttpm_log[["genotype","treat_ZT",gid]]
    sublog.groupby(["genotype","treat_ZT"]).mean().reset_index()
    slp = sublog.pivot_table(index="genotype",columns="treat_ZT",values=gid).reset_index()
    for c in slp.columns:
        if c!="genotype":
            slp.rename(columns={c:gid+"_"+c},inplace=True)
    return slp

# %%
dflist = []
for c in vttpm_log.columns:
    if c.startswith("Y"):
        dflist.append(genemeans(c))

# %%
dflist[0].head()
# Out:
# treat_ZT genotype  Yucal.01G000100.v2.1_D_1  Yucal.01G000100.v2.1_D_13  \
# 0              12                  4.671265                   4.921500
# 1              13                  5.144395                   4.975804
# 2              18                  5.684827                   5.435823
# 3              19                  5.135665                   5.190652
# 4             1AB                  5.494941                   5.422841
#
# treat_ZT  Yucal.01G000100.v2.1_D_17  Yucal.01G000100.v2.1_D_21  \
# 0                          5.005791                   4.798222
# 1                          4.853688                   5.012945
# 2                          5.405006                   5.475807
# 3                          5.463501                   5.250987
# 4                          5.219464                   4.980347
#
# treat_ZT  Yucal.01G000100.v2.1_D_5  Yucal.01G000100.v2.1_D_9  \
# 0                         4.095183                  4.459452
# 1                         4.893604                  5.055911
# 2                         5.751970                  5.898819
# 3                         4.594409                  5.076206
# 4                         5.043138                  5.326056
#
# treat_ZT  Yucal.01G000100.v2.1_W_1  Yucal.01G000100.v2.1_W_13  \
# 0                         4.871347                   4.712149
# 1                         5.258964                   5.489978
# 2                         5.573681                   5.574150
# 3                         5.157064                   5.322314
# 4                         5.546432                   5.651210
#
# treat_ZT  Yucal.01G000100.v2.1_W_17  Yucal.01G000100.v2.1_W_21  \
# 0                          4.941031                   5.006829
# 1                          5.268651                   5.200845
# 2                          5.244135                   5.290898
# 3                          5.205319                   4.971768
# 4                          5.358873                   5.537470
#
# treat_ZT  Yucal.01G000100.v2.1_W_5  Yucal.01G000100.v2.1_W_9
# 0                         4.102163                  4.456983
# 1                         4.848472                  5.053348
# 2                         6.075920                  5.711747
# 3                         4.843764                  5.160359
# 4                         5.627045                  5.456193

# %%
len(dflist)
# Out:
# 81819

# %%
allfeatures = reduce(lambda x,y: pd.merge(x,y,on="genotype"),dflist)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 allfeatures = reduce(lambda x,y: pd.merge(x,y,on="genotype"),dflist)
#
# Input In [33], in <lambda>(x, y)
# ----> 1 allfeatures = reduce(lambda x,y: pd.merge(x,y,on="genotype"),dflist)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/reshape/merge.py:122, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
#     107     op = _MergeOperation(
#     108         left,
#     109         right,
#    (...)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/reshape/merge.py:725, in _MergeOperation.get_result(self)
#     722 lindexers = {1: left_indexer} if left_indexer is not None else {}
#     723 rindexers = {1: right_indexer} if right_indexer is not None else {}
# --> 725 result_data = concatenate_managers(
#     726     [(self.left._mgr, lindexers), (self.right._mgr, rindexers)],
#     727     axes=[llabels.append(rlabels), join_index],
#     728     concat_axis=0,
#     729     copy=self.copy,
#     730 )
#     732 typ = self.left._constructor
#     733 result = typ(result_data).__finalize__(self, method=self._merge_type)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/concat.py:242, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     240     fastpath = blk.values.dtype == values.dtype
#     241 else:
# --> 242     values = _concatenate_join_units(join_units, concat_axis, copy=copy)
#     243     fastpath = False
#     245 if fastpath:
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/concat.py:545, in _concatenate_join_units(join_units, concat_axis, copy)
#     542 has_none_blocks = any(unit.block.dtype.kind == "V" for unit in join_units)
#     543 upcasted_na = _dtype_to_na_value(empty_dtype, has_none_blocks)
# --> 545 to_concat = [
#     546     ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)
#     547     for ju in join_units
#     548 ]
#     550 if len(to_concat) == 1:
#     551     # Only one block, nothing to concatenate.
#     552     concat_values = to_concat[0]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/concat.py:546, in <listcomp>(.0)
#     542 has_none_blocks = any(unit.block.dtype.kind == "V" for unit in join_units)
#     543 upcasted_na = _dtype_to_na_value(empty_dtype, has_none_blocks)
#     545 to_concat = [
# --> 546     ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)
#     547     for ju in join_units
#     548 ]
#     550 if len(to_concat) == 1:
#     551     # Only one block, nothing to concatenate.
#     552     concat_values = to_concat[0]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/concat.py:525, in JoinUnit.get_reindexed_values(self, empty_dtype, upcasted_na)
#     523 else:
#     524     for ax, indexer in self.indexers.items():
# --> 525         values = algos.take_nd(values, indexer, axis=ax)
#     527 return values
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/array_algos/take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/array_algos/take.py:161, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     157 else:
#     158     out = np.empty(out_shape, dtype=dtype)
#     160 func = _get_take_nd_function(
# --> 161     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     162 )
#     163 func(arr, indexer, out, fill_value)
#     165 if flip_order:
#
# KeyboardInterrupt:
